# %%
import warnings
import os
import sys
warnings.filterwarnings('ignore')

project_root = os.path.abspath("..")  
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from src.simulation_runner import plot_snr_vs_mi_with_shaded_std

# %%
plot_snr_vs_mi_with_shaded_std(
    sim_folder = sys.path[0] + '/simulation_results',
    mi_estimators=["BA","CORTICAL",'BruteForce'],
    dimensions=[1],
    num_thresholds_list=[1,2,3],
    run_ids=["-","run3","run2","run4"],
    channel_types=["identity-csi"],
    sim_counts=[i for i in range(10)],
    num_std = 1,
    style_mapping = {
        'color': 'mi_estimator',
        'marker': 'num_thresholds',
        'linestyle': 'channel_type'
    }
)

# %%
plot_snr_vs_mi_with_shaded_std(
    sim_folder = sys.path[0] + '/simulation_results',
    mi_estimators=["BA","CORTICAL",'BruteForce','QAM','PSK'],
    dimensions=[2],
    num_thresholds_list=[2,3,4],
    run_ids=["-",'run10','run2'],
    channel_types=["identity-csi"],
    sim_counts=[i for i in range(10)],
    num_std = 1,
    style_mapping = {
        'color': 'mi_estimator',
        'marker': 'num_thresholds',
        'linestyle': 'channel_type'
    }
)

# %%
plot_snr_vs_mi_with_shaded_std(
    sim_folder = sys.path[0] + '/simulation_results',
    mi_estimators=["BA"],
    dimensions=[2],
    num_thresholds_list=[2,4],
    run_ids=["-","run10"],
    channel_types=['identity-csi','noisy-csi-0.01','noisy-csi-0.05',
                   'noisy-csi-0.1'],
    sim_counts=[i for i in range(10)],
    num_std = 1,
    style_mapping = {
        'color': 'channel_type',
        'marker': 'num_thresholds',
        'linestyle': 'mi_estimator'
    }
)

# %%
plot_snr_vs_mi_with_shaded_std(
    sim_folder = sys.path[0] + '/simulation_results',
    mi_estimators=["BA"],
    dimensions=[2],
    num_thresholds_list=[2,4],
    run_ids=["-","run10"],
    channel_types=['identity-csi','changing-csi-smooth-0.05','changing-csi-smooth-0.01'],
    sim_counts=[i for i in range(10)],
    num_std = 1,
    style_mapping = {
        'color': 'channel_type',
        'marker': 'num_thresholds',
        'linestyle': 'mi_estimator'
    }
)
